# %% [markdown]
# <a href="https://colab.research.google.com/github/hosseinrezaie0/PPE-Detection/blob/main/Fine%20Tune/finetune.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Personal Protective Equipment

# %% [markdown]
# ## Install & Import Dependencies

# %%
# !pip install ultralytics roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 39.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 68.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 75.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo mode=checks
from roboflow import Roboflow
import glob
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/cfg/__init__.py", line 917, in entrypoint
#     raise ValueError(f"Invalid 'mode={mode}'. Valid modes are {list(MODES)}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'mode=checks'. Valid modes are ['benchmark', 'predict', 'train', 'track', 'val', 'export'].
#
#     Arguments received: ['yolo', 'mode=checks']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of ['classify', 'pose', 'detect', 'segment', 'obb']
#                 MODE (required) is one of ['benchmark', 'predict', 'train', 'track', 'val', 'export']
#                 ARGS (optional) are any number of custom 'arg=value' pairs like 'imgsz=320' that override defaults.
# ...

# %% [markdown]
# ## Initialize Configuration

# %%
# Load the Roboflow dataset
rf = Roboflow(api_key="")
project = rf.workspace("").project("")
latest_version = project.version(1)
dataset = latest_version.download("yolov8")
print(f"Downloaded dataset version: {latest_version.version}")
print(f"Dataset path: {dataset.location}")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to PPE-Detection-1 in yolov8:: 100%|██████████| 10670/10670 [00:03<00:00, 3439.30it/s]
# Downloaded dataset version: 1
# Dataset path: /content/PPE-Detection-1

# %%
train_images = glob.glob('/content/PPE-Detection-1/train/images/*.jpg')
val_images = glob.glob('/content/PPE-Detection-1/valid/images/*.jpg')
test_images = glob.glob('/content/PPE-Detection-1/test/images/*.jpg')
print(f"Number of training images: {len(train_images)}")
print(f"Number of validation images: {len(val_images)}")
print(f"Number of testing images: {len(test_images)}")
# Out:
# Number of training images: 4698
# Number of validation images: 420
# Number of testing images: 211

# %% [markdown]
# ## Train the model

# %%
# train the model
# !yolo task=detect mode=train model=yolov8n.pt data={dataset.location}/data.yaml epochs=50 imgsz=640
# Out:
# ...
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=val model=runs/detect/train/weights/best.pt data={dataset.location}/data.yaml split=test
# Out:
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,006,623 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2075.1±542.1 MB/s, size: 71.6 KB)
# val: Scanning /content/PPE-Detection-1/test/labels... 211 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 211/211 2.1Kit/s 0.1s
# val: New cache created: /content/PPE-Detection-1/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.7it/s 3.8s
#                    all        211        877      0.961      0.962      0.974      0.828
#                  boots        146        286      0.978      0.986      0.994      0.798
#                 gloves          9         16      0.902      0.875      0.924      0.733
#                 helmet        146        165      0.962      0.994      0.974      0.792
# ...
